# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('PastHires.csv')

display(df)

print(f"The rows and cols of our df is{df.shape}")
print(f"The size, or rows * cols of our df is {df.size}")
print(f"The number of rows is {len(df)}")
print(f"To get the column names in an array:\n {df.columns}")
# print(f"To get just one column:\n{df['Years Experience']}")
# print(f"To get multiple cols:\n{df[['Years Experience', 'Hired']]}")
print(f"To sort the df by a col:\n{df.sort_values('Years Experience')}")

degree_counts = df['Level of Education'].value_counts()
degree_counts_list = list(degree_counts)
degree_counts_dict = dict(degree_counts)

print(degree_counts)
print(degree_counts_list)
print(degree_counts_dict)
# print(f"To get num of unique vals of a col:\n{)}")

df_synth = df[['Previous Employers', 'Hired']][5:10]

display(df_synth)

plt.hist(df_synth['Previous Employers'], bins=3)

plt.show()
# Out:
#    Years Experience Employed  Previous Employers Level of Education  \
# 0                 0        Y                   4                 BS
# 1                 0        N                   0                 BS
# 2                 7        N                   6                 BS
# 3                 2        Y                   1                 MS
# 4                20        N                   2                PhD
# 5                 8        Y                   1                 BS
# 6                13        Y                   2                PhD
# 7                 1        Y                   0                 MS
# 8                 4        Y                   0                 BS
# 9                17        Y                   3                 MS
#
#   Top-Tier School Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N
# ...
